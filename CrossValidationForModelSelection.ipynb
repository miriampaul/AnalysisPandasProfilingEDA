# %% [markdown]
# <a href="https://colab.research.google.com/github/miriampaul/AnalysisPandasProfilingEDA/blob/main/CrossValidationForModelSelection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Compare multiple classifiers for different train and test values
import pandas as pd
data=pd.read_csv("/content/04+-+decisiontreeAdultIncome (1).csv")
data_prep=pd.get_dummies(data, drop_first=True)

# %%
data_prep
# Out:
#        age  hours per week  wc_ Local-gov  wc_ Never-worked  wc_ Private  \
# 0       38              40          False             False         True
# 1       28              40          False             False         True
# 2       37              40          False             False         True
# 3       31              50          False             False         True
# 4       42              40          False             False         True
# ...    ...             ...            ...               ...          ...
# 19782   53              40          False             False         True
# 19783   22              40          False             False         True
# 19784   40              40          False             False         True
# 19785   58              40          False             False         True
# 19786   22              20          False             False         True
#
#        education_ Doctorate  education_ HS-grad  education_ Masters  \
# 0                     False                True               False
# 1                     False               False               False
# 2                     False               False                True
# 3                     False               False                True
# 4                     False               False               False
# ...                     ...                 ...                 ...
# 19782                 False               False                True
# 19783                 False               False               False
# 19784                 False                True               False
# 19785                 False                True               False
# 19786                 False                True               False
#
#        education_ Preschool  education_ Prof-school  education_ Some-college  \
# 0                     False                   False                    False
# 1                     False                   False                    False
# 2                     False                   False                    False
# 3                     False                   False                    False
# 4                     False                   False                    False
# ...                     ...                     ...                      ...
# 19782                 False                   False                    False
# 19783                 False                   False                     True
# 19784                 False                   False                    False
# 19785                 False                   False                    False
# 19786                 False                   False                    False
#
#        marital status_ Never-married  marital status_ Widowed  \
# 0                              False                    False
# 1                              False                    False
# 2                              False                    False
# 3                               True                    False
# 4                              False                    False
# ...                              ...                      ...
# 19782                          False                    False
# 19783                           True                    False
# 19784                          False                    False
# 19785                          False                     True
# 19786                           True                    False
#
#        marital status_Married  race_ Asian-Pac-Islander  race_ Black  \
# 0                       False                     False        False
# 1                        True                     False         True
# 2                        True                     False        False
# 3                       False                     False        False
# 4                        True                     False        False
# ...                       ...                       ...          ...
# 19782                    True                     False        False
# 19783                   False                     False        False
# 19784                    True                     False        False
# 19785                   False                     False        False
# 19786                   False                     False        False
#
#        race_ Other  race_ White  gender_ Male  IncomeClass_ >50K
# 0            False         True          True              False
# 1            False        False         False              False
# 2            False         True         False              False
# 3            False         True         False               True
# 4            False         True          True               True
# ...            ...          ...           ...                ...
# 19782        False         True          True               True
# 19783        False         True          True              False
# 19784        False         True          True               True
# 19785        False         True         False              False
# 19786        False         True          True              False
#
# [19787 rows x 20 columns]

# %%
#Create the X and Y variables
X=data_prep.iloc[:, :-1]
Y=data_prep.iloc[:,-1]

# %%
#Import and train the Devision tree classifier
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier(random_state=1234)

# %%
#IMport and train Random FOrest classifier
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(random_state=1234)

# %%
#Import and train support vector classifier
from sklearn.svm import SVC
svc=SVC(kernel='rbf', gamma=0.5)

# %%
svc
# Out:
# SVC(gamma=0.5)

# %%
#Cross validation
from sklearn.model_selection import cross_validate

# %%
#Store the cv results
cv_result_dtc=cross_validate(dtc, X, Y, cv=10, return_train_score=True)

# %%
cv_result_rfc=cross_validate(rfc, X, Y, cv=10, return_train_score=True)

# %%
cv_result_svc=cross_validate(svc, X, Y, cv=10, return_train_score=True)

# %%
cv_result_rfc
# Out:
# {'fit_time': array([1.86683345, 1.52540636, 1.5120399 , 1.45995021, 1.58146405,
#         1.99085641, 1.9909761 , 1.67405152, 1.59833169, 1.53109169]),
#  'score_time': array([0.06249452, 0.0685153 , 0.06625032, 0.06829667, 0.06235242,
#         0.07153583, 0.06445885, 0.06009269, 0.06012845, 0.05875397]),
#  'test_score': array([0.79029813, 0.78524507, 0.80242547, 0.77716018, 0.81152097,
#         0.80090955, 0.80596261, 0.8124368 , 0.78816987, 0.79777553]),
#  'train_score': array([0.90397574, 0.90566038, 0.90375112, 0.90566038, 0.9035265 ,
#         0.90375112, 0.90375112, 0.90409344, 0.90527261, 0.90347577])}

# %%
cv_result_dtc
# Out:
# {'fit_time': array([0.07101393, 0.07059717, 0.07397246, 0.12985349, 0.06761527,
#         0.06264997, 0.06320119, 0.06481218, 0.06366873, 0.06295729]),
#  'score_time': array([0.00482702, 0.00558448, 0.00431013, 0.00558472, 0.00491214,
#         0.00436997, 0.00415659, 0.00428414, 0.00477409, 0.00503778]),
#  'test_score': array([0.77261243, 0.77059121, 0.78170793, 0.75593734, 0.78878221,
#         0.79535119, 0.78676099, 0.79271992, 0.77704752, 0.78918099]),
#  'train_score': array([0.90408805, 0.90571653, 0.90380728, 0.90571653, 0.90358266,
#         0.90380728, 0.90380728, 0.90414959, 0.90532877, 0.90353192])}

# %%
import numpy as np
dtc_test_average= np.average(cv_result_dtc['test_score'])

# %%
rfc_test_average= np.average(cv_result_rfc['test_score'])

# %%
svc_test_average= np.average(cv_result_svc['test_score'])

# %%
dtc_train_average=np.average(cv_result_dtc['train_score'])

# %%
rfc_train_average=np.average(cv_result_rfc['train_score'])

# %%
svc_train_average=np.average(cv_result_svc['train_score'])

# %%
#print and analyze the result
print()
print()
print('        ', 'Decision Tree', 'Random Forest ', 'Support Vector')
print("         , ---------------, ----------------, ----------------")
print('   Test   :  ',
      round(dtc_test_average, 4), "        ",
      round(rfc_test_average, 4), "         ",
      round(svc_test_average, 4))
print("   Train:   ",
      round(dtc_train_average, 4),"        ",
      round(rfc_train_average, 4), "        ",
      round(svc_train_average, 4))
# Out:
#          Decision Tree Random Forest  Support Vector
#          , ---------------, ----------------, ----------------
#    Test   :   0.7811          0.7972           0.8036
#    Train:    0.9044          0.9043          0.8745
